# %%
import pandas as pd

# %%
m = pd.read_csv("/content/Mydf.csv")
m
# Out:
#     Unnamed: 0   Names Initials  SEM1  SEM2  SEM3 GPA  Placed Conduct  \
# 0            0     Joe        K   9.8  10.0   9.9  A+       1    Good
# 1            1  Rajesh        M   8.9   9.1   9.3   A       1    Good
# 2            2  Kissan        V   9.9   9.8  10.0   A       0    Good
# 3            3    Mary        N   7.7   8.0   NaN   B       0    Good
# 4            4    Jeen        K   9.8   9.1   9.9  A+       1    Good
# 5            5     Raj        M   8.9   9.1   9.3   A       1    Good
# 6            6  Hassan        V   9.9   9.0   9.2   A       1    Good
# 7            7    Mari        N   7.7   8.0   7.1   B       1    Good
# 8            8    Jess        K   NaN   9.1   9.9  A+       1    Good
# 9            9  Rajini        M   NaN   9.1   9.3   A       0    Good
# 10          10   Kiran        V   NaN   9.3   9.2   A       0    Good
# 11          11    Maya        N   7.7   8.0   7.1   B       0    Good
# ...

# %%
import seaborn as sns   #seaborn is completely dedicated for visualisation

# %%
pl = sns.lineplot(x='Names',y='SEM1',data=m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3c598d58b90c> in <cell line: 1>()
# ----> 1 pl = sns.lineplot(x='Names',y='SEM1',data=m)
#
# NameError: name 'm' is not defined

# %%
d = pd.read_excel("/content/diabetes.excel (1).xlsx")

# %%
pl = sns.relplot(data=m , x='SEM1',y='Names',col = "Placed")
# col--> graphs are seperated  based on this col

# %% [markdown]
# problem:
# create a relational plot age as y axis index as x axis seperated by class

# %%
d.head()
d.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768

# %%
d['Index'] = range(1,769)

# %%
p = sns.relplot(data = d , x = 'Index', y =  'age' , col = 'class')

# %% [markdown]
# seaborn has many of its own csv files like :fmri,tips,dowjones,healthexp,dots
# showing the difference using color called hue

# %%
sns.relplot(data=tips,x= "total_bill",y = "tip" , hue ="smoker" , style = "time", palette="bright")

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips, x= "total_bill",y = "tip" , hue ="smoker")
#hue - creating difference based on a column via colors

# %%
sns.relplot(data=tips, x= "total_bill",y = "tip" , hue ="sex")

# %%
sns.relplot(data=tips,x= "total_bill",y = "tip" , hue ="size")

# %%
dj = sns.load_dataset("dowjones")

# %%
sns.relplot(data=dj, x="Date", y= "Price",kind="line")
# by default relplot have scatter plot if we dont mention kind it gives defaultly scatter

# %%
f = sns.load_dataset("fmri")

# %%
f.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=f, x="timepoint", y= "signal")

# %%
sns.catplot(data=tips, x="total_bill", y= "day")
#category plot based on y

# %%
sns.catplot(data=tips, x="total_bill", y= "smoker")

# %%
sns.catplot(data=tips, y="total_bill", x= "time",kind = "violin",hue ="smoker")

# %%
sns.catplot(data=tips, y="total_bill", x= "time",kind = "violin")

# %%
sns.catplot(data=tips, y="total_bill", x= "time",kind = "box",hue ="smoker")

# %%
sns.catplot(data=tips, y="total_bill", x= "time",kind = "box")

# %%
sns.catplot(data=tips, y="total_bill", x= "time",kind = "boxen")    #own

# %%
import seaborn as sns

# %%
cc = sns.load_dataset("car_crashes")
cc
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
cc.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
cc.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
s = sns.lineplot(x = 'alcohol', y = 'speeding' , data =cc)

# %%
sns.relplot( data = cc ,x = 'alcohol', y = 'speeding' ,  col = "total")

# %%
 sns.relplot( data = cc ,x = 'alcohol', y = 'speeding' ,  col = "total", style = "total",hue = "abbrev",palette="deep")

# %%
 sns.relplot( data = cc ,x = 'alcohol', y = 'speeding' ,  col = "abbrev" ,kind ='line')

# %%
 sns.relplot( data = cc ,x = 'ins_premium', y = 'ins_losses' ,  hue= "total" , palette = "dark")

# %%
 sns.catplot( data = cc ,x = 'total', y = 'alcohol' ,  hue= "total"  , palette = "dark")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
 sns.catplot( data = cc ,x = 'not_distracted', y = 'no_previous' ,  hue= "total" ,kind = "boxen", palette = "dark")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(data=iris,x="sepal_length",y="petal_width",kind="line",hue="species")

# %%
sns.catplot(data=iris,x="sepal_length",y="petal_width",kind="boxen",hue="species",palette="dark")

# %%
sns.catplot(data=iris,x="sepal_length",y="petal_width",kind="point",hue="species",palette="dark")

# %%
sns.catplot(data=iris,x="sepal_length",y="petal_width",kind="bar",hue="species",palette="dark")

# %%
he=sns.load_dataset("healthexp")
he.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.catplot(data=he,x="Life_Expectancy",y="Year",kind="bar",hue="Country",palette="bright")

# %%
sns.relplot(data=he,x="Life_Expectancy",y="Year",kind="scatter",hue="Country",palette="bright")

# %%
sns.catplot(data=he,x="Life_Expectancy",y="Year",kind="strip",hue="Country",palette="bright")
