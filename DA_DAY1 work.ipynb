# %%
a=[8,6,7,12,3,5]
b=sorted(a)
print(b)
# Out:
# [3, 5, 6, 7, 8, 12]

# %%
a=(8,6,7,12,3,5)
b=sorted(a)
print(a)
print(b)
# Out:
# (8, 6, 7, 12, 3, 5)
# [3, 5, 6, 7, 8, 12]

# %%
tuple1=(1,2,"college",9)
tuple2=()
tuple3=tuple((1,3,5,9,"hello"))
print(tuple1)
print(tuple2)
print(tuple3)
# Out:
# (1, 2, 'college', 9)
# ()
# (1, 3, 5, 9, 'hello')

# %%
tuple1=("good",1,2,3,"morning")
print(tuple1)
print(tuple1[0])
tuple2=("orange","grapes")
print
tuple3=(1,2,3)
print(type(tuple3))
# Out:
# ('good', 1, 2, 3, 'morning')
# good
# <class 'tuple'>

# %%
tuple1=(1,3,6,7,9,10)
print(tuple1.index(6))
print(tuple1.index(9))
# Out:
# 2
# 4

# %%
set1={1,2,3,4,5,"hello","tup"}
set2={(1,8,"python",7)}
print(set1)
print(set2)
# Out:
# {1, 2, 3, 4, 5, 'hello', 'tup'}
# {(1, 8, 'python', 7)}

# %%
set1={"water","air","food"}
set1.add("shelter")
print(set1)
set1.add("clothes")
print(set1)
set1.pop()
print(set1)
# Out:
# {'food', 'shelter', 'water', 'air'}
# {'water', 'food', 'air', 'clothes', 'shelter'}
# {'food', 'air', 'clothes', 'shelter'}

# %%
set1={1,2,3,4,5}
print(set1)
set2={3,7,1,6,1}
print(set2)
# Out:
# {1, 2, 3, 4, 5}
# {1, 3, 6, 7}

# %%
import requests
api_key='8c909421a6514fdda6853627242802'
city="Tadepalligudem"
url=f"https://api.weatherapi.com/v1/current.json?key=<{api_key}>&q={city}"
response=requests.get(url)
data=response.json()
print(data)
